# %%
# ssplit

from pycorenlp import StanfordCoreNLP
nlp = StanfordCoreNLP('http://localhost:9000')

text = ('M and N walked towards the city. They did not want to walk back')

output = nlp.annotate(text, properties={
    'annotators': 'ssplit',
    'outputFormat': 'json'
})

print(output)
# Out:
# {'sentences': [{'index': 0, 'tokens': [{'index': 1, 'word': 'M', 'originalText': 'M', 'characterOffsetBegin': 0, 'characterOffsetEnd': 1, 'before': '', 'after': ' '}, {'index': 2, 'word': 'and', 'originalText': 'and', 'characterOffsetBegin': 2, 'characterOffsetEnd': 5, 'before': ' ', 'after': ' '}, {'index': 3, 'word': 'N', 'originalText': 'N', 'characterOffsetBegin': 6, 'characterOffsetEnd': 7, 'before': ' ', 'after': ' '}, {'index': 4, 'word': 'walked', 'originalText': 'walked', 'characterOffsetBegin': 8, 'characterOffsetEnd': 14, 'before': ' ', 'after': ' '}, {'index': 5, 'word': 'towards', 'originalText': 'towards', 'characterOffsetBegin': 15, 'characterOffsetEnd': 22, 'before': ' ', 'after': ' '}, {'index': 6, 'word': 'the', 'originalText': 'the', 'characterOffsetBegin': 23, 'characterOffsetEnd': 26, 'before': ' ', 'after': ' '}, {'index': 7, 'word': 'city', 'originalText': 'city', 'characterOffsetBegin': 27, 'characterOffsetEnd': 31, 'before': ' ', 'after': ''}, {'index': 8, 'w
# ...

# %% [markdown]
# ####[Formatted json](https://github.com/lilcser/NLP/blob/master/ssplit.json)

# %%
# comparison ssplit vs tokenization
# 1. each sentence is stored in one index
# 2. 'before' and 'after' tag for each token 

from IPython.display import Image
Image(filename="img/ssplit vs tokenization.png")
